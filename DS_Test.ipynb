# %% [markdown]
# # Data Science Test
#
# **Exam duration:**
# 24 hours
#
# **Required output:**
# The uploaded solution must be an ipython notebook (a file of type `ipynb`). All code must be written in python. All text must be written in Markdown.
#
# You may use Colab, Jupyter lab, Jupyter notebook or any other program to complete the exam.
#
# Upload your solution to Github before the deadline. You will get the upload link at bottom of the test.
#
# #### Before submission
#
# Make sure you are submitting error free code!
#
# Click Run --> Restart Kernal and Run all cells.
#
# #### Honor code
#
# As a student of AI Adventures, I **[enter_your_name here]** pledge to:
#
# 1. Uphold the values of academic integrity, honesty, and respect in all of my academic work.
#
# 2. Not engage in any form of academic misconduct, including cheating, plagiarism, or using unauthorized resources during exams.
#
# 3. Commit to not using ChatGPT or any other AI language model during exam hours, and to rely only on my own knowledge, skills, and resources.
#
# 4. Follow all exam rules and instructions, and not bring any unauthorized materials, devices, or resources into the exam room.
#
# 5. Report any incidents of academic misconduct that I witness or become aware of, and cooperate fully with any investigation into such incidents.
#
# 6. Not ask mentors questions that relate directly to coding during exams, such as "why does my code snippet not work as expected?" or "how do I implement...?"
#
# 7. If I am stuck with implementation during an exam, I am allowed to use Google as a resource.
#
# By signing this pledge, I commit to upholding the highest standards of academic integrity and to avoiding all forms of cheating or academic misconduct during my studies at AI Adventures. I understand that violating this pledge may result in disciplinary actions.

# %% [markdown]
# #### Answering the questions
# Most of the questions require you to implement something in Python but there might be some questions for which you do not need to write any code.
#
# For code questions (that is - almost all questions): you are required to show the **python** code you used to find the answer. An answer found using excel or other tools will not be accepted. The code should also be general, so that it would still work if the data were to change.
#
# The code output should only show the answer to the question with no extras. For example: if asked on 2018 data, show only 2018 data (and not 2015-2017 data in addition).
#
# We provide cells in which you can type your answer. Use can modify the to `Code` or `Markdown`. Use `Code` to write python code, and `Markdown` for explanations.
#
# You are not required to use all the cells we provide, and you are also not required to use only the cells we provide. You may add or remove answer cell as you need.

# %% [markdown]
# #### Libraries
#
# To answer the questions you may use:
# - any library you prefer (not necessarily the ones which were presented in the course)
# - all materials that we have provided you during the courses
# - the whole www (especially documentation of libraries and sites like stackoverflow may give you useful hints)
#
# In case something does not work as expected, check that you have the most recent version of the library.
#
# You can update your used libraries with a command like the following:

# %%
# !pip install -U <library_name>
# remove the '#' sign in case you want to update any of the libraries

# %% [markdown]
# # Good Luck!

# %% [markdown]
# ---

# %% [markdown]
# ## The dataset
#
# Wildlife strikes with aircraft are increasing worldwide. Collecting and analyzing accurate data on wildlife strikes helps to better understand the scope and nature of the problem.\
# In this exam, you will work with data on aircraft-wildlife collisions, courtesy of the [Federal Aviation Administration](https://wildlife.faa.gov/search)\
# This dataset contains reports received from airlines, airports, pilots on aircraft collisions with wildlife.\
# See the file: `about_the_dataset.xlsx` for an explanation on the columns in the dataset.

# %% [markdown]
# ## Task 1 - Code of honor (mandatory, no points):

# %% [markdown]
# Please copy the following sentence and add your full name:
#
# As a student of AI Adventures, I `enter_your_name here` pledge to:
#
# 1. Uphold the values of academic integrity, honesty, and respect in all of my academic work.
#
# 2. Not engage in any form of academic misconduct, including cheating, plagiarism, or using unauthorized resources during exams.
#
# 3. Commit to not using ChatGPT or any other AI language model during exam hours, and to rely only on my own knowledge, skills, and resources.
#
# 4. Follow all exam rules and instructions, and not bring any unauthorized materials, devices, or resources into the exam room.
#
# 5. Report any incidents of academic misconduct that I witness or become aware of, and cooperate fully with any investigation into such incidents.
#
# 6. Not ask mentors questions that relate directly to coding during exams, such as "why does my code snippet not work as expected?" or "how do I implement...?"
#
# 7. If I am stuck with implementation during an exam, I am allowed to use Google as a resource.
#
# By signing this pledge, I commit to upholding the highest standards of academic integrity and to avoiding all forms of cheating or academic misconduct during my studies at AI Adventures. I understand that violating this pledge may result in disciplinary actions.

# %% [markdown]
# -------------------------------------------------------------------------------------

# %% [markdown]
# ## Task 2 - Data Import

# %%
from urllib import request
import pandas as pd
module_urls = ["https://media.githubusercontent.com/media/Ai-Adventures/Test_Datasets/main/strikes_from_2020.csv","https://media.githubusercontent.com/media/Ai-Adventures/Test_Datasets/main/strikes_until_2020.csv"]
for url in module_urls:
  print(f'Fetching {url}')
  module_name = url.split('/')[-1]
  #with open("file_1.txt") as f1, open("file_2.txt") as f2
  with request.urlopen(url) as f, open(module_name,'w') as outf:
    a = f.read()
    outf.write(a.decode('utf-8'))
# this fills empty cells with empty strings
# Out:
# Fetching https://media.githubusercontent.com/media/Ai-Adventures/Test_Datasets/main/strikes_from_2020.csv
# Fetching https://media.githubusercontent.com/media/Ai-Adventures/Test_Datasets/main/strikes_until_2020.csv

# %%
df1 = pd.read_csv('strikes_from_2020.csv')
df2 = pd.read_csv('strikes_until_2020.csv')
# Out:
# <ipython-input-4-c2e602d78ac1>:2: DtypeWarning: Columns (18,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('strikes_until_2020.csv')

# %% [markdown]
# You will find two files:\
# `strikes_until_2020.csv` - contains data on reported strikes up until 2020.\
# `strikes_from_2020.csv` - contains data on reported strikes from the beginning of 2020 and onward.
#
# #### Task 2.1
# Place the files in the same directory with this python notebook.
#
# Read the files into dataframes. If you are unsure how to import a file
# using column names from a list, have a look at the documentation of the function that you use
# for the import. You may want to look into the original csv-file to find out how to configure the import.\
# Note: you might encounter a `DtypeWarning` when reading the files. You can ignore this warning.

# %%
import pandas as pd
df1 = pd.read_csv('strikes_from_2020.csv')
df1
# Out:
#        Unnamed: 0  INDEX_NR    INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 0          224953   1082851  05/01/2021 0:00               1           2021
# 1          224997   1082943  01/01/2021 0:00               1           2021
# 2          224998   1082950  02/01/2021 0:00               1           2021
# 3          224999   1082951  02/01/2021 0:00               1           2021
# 4          225000   1082953  01/01/2021 0:00               1           2021
# ...           ...       ...              ...             ...            ...
# 31467      275498   1369388  23/11/2022 0:00              11           2022
# 31468      275499   1369389  24/11/2022 0:00              11           2022
# 31469      275500   1369390  01/08/2022 0:00               8           2022
# 31470      275501   1369391  01/08/2022 0:00               8           2022
# 31471      275502   1369392  01/08/2022 0:00               8           2022
#
#         TIME TIME_OF_DAY AIRPORT_ID                           AIRPORT  \
# 0        NaN         NaN       MNMG                 MANAGUA INTL ARPT
# 1       8:25         NaN       KRFD        CHICAGO/ROCKFORD INTL ARPT
# 2       1:01         NaN       KTPA                        TAMPA INTL
# 3       1:55         NaN       KTPA                        TAMPA INTL
# 4      15:30        Dusk       KEVV               EVANSVILLE REGIONAL
# ...      ...         ...        ...                               ...
# 31467   9:10         Day       KHPN           WESTCHESTER COUNTY ARPT
# 31468    NaN         NaN       KJFK               JOHN F KENNEDY INTL
# 31469  21:04         NaN       KCKB  NORTH CENTRAL WEST VIRGINIA ARPT
# 31470   8:14         Day       KCMH     JOHN GLENN COLUMBUS INTL ARPT
# 31471  17:40         Day       KGTR          GOLDEN TRIANGLE REGIONAL
#
#         LATITUDE  ...  ENROUTE_STATE NR_INJURIES NR_FATALITIES COMMENTS  \
# 0      12.141494  ...            NaN         NaN           NaN      NaN
# 1      42.195360  ...            NaN         NaN           NaN      NaN
# 2      27.975470  ...            NaN         NaN           NaN      NaN
# 3      27.975470  ...            NaN         NaN           NaN      NaN
# 4      38.037990  ...            NaN         NaN           NaN      NaN
# ...          ...  ...            ...         ...           ...      ...
# 31467  41.066960  ...            NaN         NaN           NaN      NaN
# 31468  40.639750  ...            NaN         NaN           NaN      NaN
# 31469  39.296640  ...            NaN         NaN           NaN      NaN
# 31470  39.996947  ...            NaN         NaN           NaN      NaN
# 31471  33.450200  ...            NaN         NaN           NaN      NaN
#
#       REPORTED_NAME REPORTED_TITLE                SOURCE  \
# 0          REDACTED       REDACTED  Air Transport Report
# 1          REDACTED       REDACTED     FAA Form 5200-7-E
# 2          REDACTED       REDACTED     FAA Form 5200-7-E
# 3          REDACTED       REDACTED     FAA Form 5200-7-E
# 4          REDACTED       REDACTED     FAA Form 5200-7-E
# ...             ...            ...                   ...
# 31467      REDACTED       REDACTED     FAA Form 5200-7-E
# 31468      REDACTED       REDACTED     FAA Form 5200-7-E
# 31469      REDACTED       REDACTED                   MOR
# 31470      REDACTED       REDACTED                   MOR
# 31471      REDACTED       REDACTED                   MOR
#
#                          PERSON          LUPDATE TRANSFER
# 0      Air Transport Operations  06/01/2021 0:00        0
# 1                 Carcass Found  06/01/2021 0:00        0
# 2                 Carcass Found  06/01/2021 0:00        0
# 3                 Carcass Found  06/01/2021 0:00        0
# 4            Airport Operations  06/01/2021 0:00        0
# ...                         ...              ...      ...
# 31467        Airport Operations  03/02/2023 0:00        0
# 31468             Carcass Found  03/02/2023 0:00        0
# 31469                     Tower  03/02/2023 0:00        0
# 31470                     Tower  03/02/2023 0:00        0
# 31471                     Tower  03/02/2023 0:00        0
#
# [31472 rows x 102 columns]

# %%
df2 = pd.read_csv('strikes_until_2020.csv')
df2
# Out:
# <ipython-input-6-0ae4476fce19>:1: DtypeWarning: Columns (18,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('strikes_until_2020.csv')
#         Unnamed: 0  INDEX_NR    INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 0                0    608247  06/05/1991 0:00               5           1991
# 1                1    608248  05/11/1993 0:00              11           1993
# 2                2    608249  02/07/1995 0:00               7           1995
# 3                3    608250  19/09/1990 0:00               9           1990
# 4                4    608251  03/05/1992 0:00               5           1992
# ...            ...       ...              ...             ...            ...
# 232403      275193   1368903  26/08/2012 0:00               8           2012
# 232404      275215   1368932  22/05/2017 0:00               5           2017
# 232405      275290   1369058  03/01/2016 0:00               1           2016
# 232406      275350   1369164  05/08/2017 0:00               8           2017
# 232407      275370   1369206  26/05/2018 0:00               5           2018
#
#          TIME TIME_OF_DAY AIRPORT_ID                              AIRPORT  \
# 0         NaN         Day       KSAT                     SAN ANTONIO INTL
# 1         NaN        Dawn       KMCI                     KANSAS CITY INTL
# 2         NaN         NaN       KMCI                     KANSAS CITY INTL
# 3         NaN         Day       KDFW          DALLAS/FORT WORTH INTL ARPT
# 4         NaN         Day       KSJC  NORMAN Y. MINETA SAN JOSE INTL ARPT
# ...       ...         ...        ...                                  ...
# 232403  22:18       Night       KJFK                  JOHN F KENNEDY INTL
# 232404   0:26       Night       KJFK                  JOHN F KENNEDY INTL
# 232405    NaN         NaN       KLGA                      LA GUARDIA ARPT
# 232406  17:00         Day       KJFK                  JOHN F KENNEDY INTL
# 232407  19:22         Day       KJFK                  JOHN F KENNEDY INTL
#
#         LATITUDE  ...  ENROUTE_STATE NR_INJURIES NR_FATALITIES  \
# 0       29.53369  ...            NaN         NaN           NaN
# 1       39.29761  ...            NaN         NaN           NaN
# 2       39.29761  ...            NaN         NaN           NaN
# 3       32.89595  ...            NaN         NaN           NaN
# 4       37.36186  ...            NaN         NaN           NaN
# ...          ...  ...            ...         ...           ...
# 232403  40.63975  ...            NaN         NaN           NaN
# 232404  40.63975  ...            NaN         NaN           NaN
# 232405  40.77724  ...            NaN         NaN           NaN
# 232406  40.63975  ...            NaN         NaN           NaN
# 232407  40.63975  ...            NaN         NaN           NaN
#
#                                                  COMMENTS REPORTED_NAME  \
# 0           SOURCE = FAA FROM 3830 /Legacy Record=100006/      REDACTED
# 1       THIS MAY BE DUPL STRIKE FOR AIR MIDWEST, BUT T...      REDACTED
# 2                                  /Legacy Record=100008/      REDACTED
# 3                                  /Legacy Record=100009/      REDACTED
# 4       A/C = FAIRCHILD METRO II (5/8/14 UPDATED A/C) ...      REDACTED
# ...                                                   ...           ...
# 232403  *** Strike Report: 2012-8-29-032402-R1( Report...      REDACTED
# 232404  *** Strike Report: 2017-5-22-050528-R4( Report...      REDACTED
# 232405  *** Strike Report: 2016-1-11-143501-R3( Report...      REDACTED
# 232406  *** Strike Report: 2017-8-6-083946-R2( Report ...      REDACTED
# 232407  *** Strike Report: 2018-5-26-195306-R3( Report...      REDACTED
#
#        REPORTED_TITLE                SOURCE                    PERSON  \
# 0            REDACTED                 Other                     Pilot
# 1            REDACTED       FAA Form 5200-7                       NaN
# 2            REDACTED  Air Transport Report  Air Transport Operations
# 3            REDACTED       FAA Form 5200-7                     Pilot
# 4            REDACTED       FAA Form 5200-7                       NaN
# ...               ...                   ...                       ...
# 232403       REDACTED     FAA Form 5200-7-E        Airport Operations
# 232404       REDACTED              Multiple                     Pilot
# 232405       REDACTED     FAA Form 5200-7-E             Carcass Found
# 232406       REDACTED     FAA Form 5200-7-E                     Pilot
# 232407       REDACTED              Multiple        Airport Operations
#
#                 LUPDATE TRANSFER
# 0       21/11/1997 0:00        0
# 1       13/05/1998 0:00        0
# 2       20/12/2007 0:00        0
# 3       21/01/1999 0:00        0
# 4       08/05/2014 0:00        0
# ...                 ...      ...
# 232403  01/02/2023 0:00        0
# 232404  01/02/2023 0:00        0
# 232405  02/02/2023 0:00        0
# 232406  02/02/2023 0:00        0
# 232407  02/02/2023 0:00        0
#
# [232408 rows x 102 columns]

# %% [markdown]
# #### Task 2.2
# How many rows and how many columns does each dataframe contain?

# %%
df1
# Out:
#        Unnamed: 0  INDEX_NR    INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 0          224953   1082851  05/01/2021 0:00               1           2021
# 1          224997   1082943  01/01/2021 0:00               1           2021
# 2          224998   1082950  02/01/2021 0:00               1           2021
# 3          224999   1082951  02/01/2021 0:00               1           2021
# 4          225000   1082953  01/01/2021 0:00               1           2021
# ...           ...       ...              ...             ...            ...
# 31467      275498   1369388  23/11/2022 0:00              11           2022
# 31468      275499   1369389  24/11/2022 0:00              11           2022
# 31469      275500   1369390  01/08/2022 0:00               8           2022
# 31470      275501   1369391  01/08/2022 0:00               8           2022
# 31471      275502   1369392  01/08/2022 0:00               8           2022
#
#         TIME TIME_OF_DAY AIRPORT_ID                           AIRPORT  \
# 0        NaN         NaN       MNMG                 MANAGUA INTL ARPT
# 1       8:25         NaN       KRFD        CHICAGO/ROCKFORD INTL ARPT
# 2       1:01         NaN       KTPA                        TAMPA INTL
# 3       1:55         NaN       KTPA                        TAMPA INTL
# 4      15:30        Dusk       KEVV               EVANSVILLE REGIONAL
# ...      ...         ...        ...                               ...
# 31467   9:10         Day       KHPN           WESTCHESTER COUNTY ARPT
# 31468    NaN         NaN       KJFK               JOHN F KENNEDY INTL
# 31469  21:04         NaN       KCKB  NORTH CENTRAL WEST VIRGINIA ARPT
# 31470   8:14         Day       KCMH     JOHN GLENN COLUMBUS INTL ARPT
# 31471  17:40         Day       KGTR          GOLDEN TRIANGLE REGIONAL
#
#         LATITUDE  ...  ENROUTE_STATE NR_INJURIES NR_FATALITIES COMMENTS  \
# 0      12.141494  ...            NaN         NaN           NaN      NaN
# 1      42.195360  ...            NaN         NaN           NaN      NaN
# 2      27.975470  ...            NaN         NaN           NaN      NaN
# 3      27.975470  ...            NaN         NaN           NaN      NaN
# 4      38.037990  ...            NaN         NaN           NaN      NaN
# ...          ...  ...            ...         ...           ...      ...
# 31467  41.066960  ...            NaN         NaN           NaN      NaN
# 31468  40.639750  ...            NaN         NaN           NaN      NaN
# 31469  39.296640  ...            NaN         NaN           NaN      NaN
# 31470  39.996947  ...            NaN         NaN           NaN      NaN
# 31471  33.450200  ...            NaN         NaN           NaN      NaN
#
#       REPORTED_NAME REPORTED_TITLE                SOURCE  \
# 0          REDACTED       REDACTED  Air Transport Report
# 1          REDACTED       REDACTED     FAA Form 5200-7-E
# 2          REDACTED       REDACTED     FAA Form 5200-7-E
# 3          REDACTED       REDACTED     FAA Form 5200-7-E
# 4          REDACTED       REDACTED     FAA Form 5200-7-E
# ...             ...            ...                   ...
# 31467      REDACTED       REDACTED     FAA Form 5200-7-E
# 31468      REDACTED       REDACTED     FAA Form 5200-7-E
# 31469      REDACTED       REDACTED                   MOR
# 31470      REDACTED       REDACTED                   MOR
# 31471      REDACTED       REDACTED                   MOR
#
#                          PERSON          LUPDATE TRANSFER
# 0      Air Transport Operations  06/01/2021 0:00        0
# 1                 Carcass Found  06/01/2021 0:00        0
# 2                 Carcass Found  06/01/2021 0:00        0
# 3                 Carcass Found  06/01/2021 0:00        0
# 4            Airport Operations  06/01/2021 0:00        0
# ...                         ...              ...      ...
# 31467        Airport Operations  03/02/2023 0:00        0
# 31468             Carcass Found  03/02/2023 0:00        0
# 31469                     Tower  03/02/2023 0:00        0
# 31470                     Tower  03/02/2023 0:00        0
# 31471                     Tower  03/02/2023 0:00        0
#
# [31472 rows x 102 columns]

# %% [markdown]
# #### Task 2.3
# Present all of column names of one of the dataframes

# %%
colname=df1.columns
colname
# Out:
# Index(['Unnamed: 0', 'INDEX_NR', 'INCIDENT_DATE', 'INCIDENT_MONTH',
#        'INCIDENT_YEAR', 'TIME', 'TIME_OF_DAY', 'AIRPORT_ID', 'AIRPORT',
#        'LATITUDE',
#        ...
#        'ENROUTE_STATE', 'NR_INJURIES', 'NR_FATALITIES', 'COMMENTS',
#        'REPORTED_NAME', 'REPORTED_TITLE', 'SOURCE', 'PERSON', 'LUPDATE',
#        'TRANSFER'],
#       dtype='object', length=102)

# %% [markdown]
# ## Task 3 - Data Preprocessing

# %% [markdown]
# #### Task 3.1
# Combine the two dataframes: `strikes_until_2020` and `strikes_from_2020` into one dataframe named `all_strikes`. \
# Present three rows of the dataframe.

# %%
all_strikes = pd.concat([df2,df1])
all_strikes.head(3)
# Out:
#    Unnamed: 0  INDEX_NR    INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR TIME  \
# 0           0    608247  06/05/1991 0:00               5           1991  NaN
# 1           1    608248  05/11/1993 0:00              11           1993  NaN
# 2           2    608249  02/07/1995 0:00               7           1995  NaN
#
#   TIME_OF_DAY AIRPORT_ID           AIRPORT  LATITUDE  ...  ENROUTE_STATE  \
# 0         Day       KSAT  SAN ANTONIO INTL  29.53369  ...            NaN
# 1        Dawn       KMCI  KANSAS CITY INTL  39.29761  ...            NaN
# 2         NaN       KMCI  KANSAS CITY INTL  39.29761  ...            NaN
#
#   NR_INJURIES NR_FATALITIES  \
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
#
#                                             COMMENTS REPORTED_NAME  \
# 0      SOURCE = FAA FROM 3830 /Legacy Record=100006/      REDACTED
# 1  THIS MAY BE DUPL STRIKE FOR AIR MIDWEST, BUT T...      REDACTED
# 2                             /Legacy Record=100008/      REDACTED
#
#   REPORTED_TITLE                SOURCE                    PERSON  \
# 0       REDACTED                 Other                     Pilot
# 1       REDACTED       FAA Form 5200-7                       NaN
# 2       REDACTED  Air Transport Report  Air Transport Operations
#
#            LUPDATE TRANSFER
# 0  21/11/1997 0:00        0
# 1  13/05/1998 0:00        0
# 2  20/12/2007 0:00        0
#
# [3 rows x 102 columns]

# %% [markdown]
# #### Task 3.2
#
# Remove from the dataframe  columns that contain more than 60,000/180,000 missing values. How many columns are left?\
# Note: in this question, as in the next ones, make sure to assign back to `all_strikes`

# %%
missing_values = all_strikes.isnull().sum()
columns_to_remove = missing_values[missing_values > 180000].index
all_strikes = all_strikes.drop(columns=columns_to_remove)
num_columns_left = all_strikes.shape[1]
all_strikes
# Out:
#        Unnamed: 0  INDEX_NR    INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 0               0    608247  06/05/1991 0:00               5           1991
# 1               1    608248  05/11/1993 0:00              11           1993
# 2               2    608249  02/07/1995 0:00               7           1995
# 3               3    608250  19/09/1990 0:00               9           1990
# 4               4    608251  03/05/1992 0:00               5           1992
# ...           ...       ...              ...             ...            ...
# 31467      275498   1369388  23/11/2022 0:00              11           2022
# 31468      275499   1369389  24/11/2022 0:00              11           2022
# 31469      275500   1369390  01/08/2022 0:00               8           2022
# 31470      275501   1369391  01/08/2022 0:00               8           2022
# 31471      275502   1369392  01/08/2022 0:00               8           2022
#
#         TIME TIME_OF_DAY AIRPORT_ID                              AIRPORT  \
# 0        NaN         Day       KSAT                     SAN ANTONIO INTL
# 1        NaN        Dawn       KMCI                     KANSAS CITY INTL
# 2        NaN         NaN       KMCI                     KANSAS CITY INTL
# 3        NaN         Day       KDFW          DALLAS/FORT WORTH INTL ARPT
# 4        NaN         Day       KSJC  NORMAN Y. MINETA SAN JOSE INTL ARPT
# ...      ...         ...        ...                                  ...
# 31467   9:10         Day       KHPN              WESTCHESTER COUNTY ARPT
# 31468    NaN         NaN       KJFK                  JOHN F KENNEDY INTL
# 31469  21:04         NaN       KCKB     NORTH CENTRAL WEST VIRGINIA ARPT
# 31470   8:14         Day       KCMH        JOHN GLENN COLUMBUS INTL ARPT
# 31471  17:40         Day       KGTR             GOLDEN TRIANGLE REGIONAL
#
#         LATITUDE  ...       NUM_SEEN NUM_STRUCK    SIZE  \
# 0      29.533690  ...              1          1  Medium
# 1      39.297610  ...  More than 100     11-100  Medium
# 2      39.297610  ...            NaN          1  Medium
# 3      32.895950  ...         02-Oct     02-Oct   Small
# 4      37.361860  ...              1          1   Small
# ...          ...  ...            ...        ...     ...
# 31467  41.066960  ...              1        NaN  Medium
# 31468  40.639750  ...            NaN          1   Small
# 31469  39.296640  ...            NaN          1   Small
# 31470  39.996947  ...            NaN     02-Oct     NaN
# 31471  33.450200  ...            NaN          1     NaN
#
#                                                 COMMENTS REPORTED_NAME  \
# 0          SOURCE = FAA FROM 3830 /Legacy Record=100006/      REDACTED
# 1      THIS MAY BE DUPL STRIKE FOR AIR MIDWEST, BUT T...      REDACTED
# 2                                 /Legacy Record=100008/      REDACTED
# 3                                 /Legacy Record=100009/      REDACTED
# 4      A/C = FAIRCHILD METRO II (5/8/14 UPDATED A/C) ...      REDACTED
# ...                                                  ...           ...
# 31467                                                NaN      REDACTED
# 31468                                                NaN      REDACTED
# 31469                                                NaN      REDACTED
# 31470                                                NaN      REDACTED
# 31471                                                NaN      REDACTED
#
#       REPORTED_TITLE                SOURCE                    PERSON  \
# 0           REDACTED                 Other                     Pilot
# 1           REDACTED       FAA Form 5200-7                       NaN
# 2           REDACTED  Air Transport Report  Air Transport Operations
# 3           REDACTED       FAA Form 5200-7                     Pilot
# 4           REDACTED       FAA Form 5200-7                       NaN
# ...              ...                   ...                       ...
# 31467       REDACTED     FAA Form 5200-7-E        Airport Operations
# 31468       REDACTED     FAA Form 5200-7-E             Carcass Found
# 31469       REDACTED                   MOR                     Tower
# 31470       REDACTED                   MOR                     Tower
# 31471       REDACTED                   MOR                     Tower
#
#                LUPDATE TRANSFER
# 0      21/11/1997 0:00        0
# 1      13/05/1998 0:00        0
# 2      20/12/2007 0:00        0
# 3      21/01/1999 0:00        0
# 4      08/05/2014 0:00        0
# ...                ...      ...
# 31467  03/02/2023 0:00        0
# 31468  03/02/2023 0:00        0
# 31469  03/02/2023 0:00        0
# 31470  03/02/2023 0:00        0
# 31471  03/02/2023 0:00        0
#
# [263880 rows x 88 columns]

# %% [markdown]
# Task 3.3
# Remove columns that contain the same values in ALL rows.\
# Print the names of the columns you removed.

# %%
columns_to_remove =all_strikes.columns[all_strikes.nunique()==1].tolist()
for column in all_strikes.columns:
    if all(all_strikes[column] == all_strikes.iloc[0][column]):
     columns_to_remove.append(column)
all_strikes = all_strikes.drop(columns=columns_to_remove)
print("remove columns:",columns_to_remove)
# Out:
# remove columns: ['STR_STR', 'REPORTED_NAME', 'REPORTED_TITLE', 'TRANSFER', 'STR_STR', 'REPORTED_NAME', 'REPORTED_TITLE', 'TRANSFER']

# %% [markdown]
# #### Task 3.4
#
# Set the datatype of the date column to be of type datetime.\
# This may prove to be a little tricky. You can use: `all_strikes['INCIDENT_DATE'].str[:-5]` to help.

# %%
all_strikes['INCIDENT_DATE'] = pd.to_datetime(all_strikes['INCIDENT_DATE'].str[:10])
all_strikes['INCIDENT_DATE']
# Out:
# <ipython-input-12-b6604e51971b>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   all_strikes['INCIDENT_DATE'] = pd.to_datetime(all_strikes['INCIDENT_DATE'].str[:10])
# 0       1991-06-05
# 1       1993-05-11
# 2       1995-02-07
# 3       1990-09-19
# 4       1992-03-05
#            ...
# 31467   2022-11-23
# 31468   2022-11-24
# 31469   2022-01-08
# 31470   2022-01-08
# 31471   2022-01-08
# Name: INCIDENT_DATE, Length: 263880, dtype: datetime64[ns]

# %% [markdown]
# #### Task 3.5
#
# The `NUM_STRUCK` column should report the number of birds that struck the aircraft.\
# Print all the unique values in this column (for example, if this column contains only `11` and `22` then print: 11, 22)

# %%
unique_values = all_strikes['NUM_STRUCK'].unique()
print(','.join(map(str, unique_values)))
# Out:
# 1,11-100,02-Oct,nan,More than 100

# %% [markdown]
# #### Task 3.6
#
# For the `NUM_STRUCK` column, replace the value: `02-Oct` with the value: `2-10`\
# Then, reprint all unique values in this column.

# %%
all_strikes['NUM_STRUCK'] = all_strikes['NUM_STRUCK'].str.replace('02-Oct', '2-10')
unique_values = all_strikes['NUM_STRUCK'].unique()
all_strikes
# Out:
#        Unnamed: 0  INDEX_NR INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 0               0    608247    1991-06-05               5           1991
# 1               1    608248    1993-05-11              11           1993
# 2               2    608249    1995-02-07               7           1995
# 3               3    608250    1990-09-19               9           1990
# 4               4    608251    1992-03-05               5           1992
# ...           ...       ...           ...             ...            ...
# 31467      275498   1369388    2022-11-23              11           2022
# 31468      275499   1369389    2022-11-24              11           2022
# 31469      275500   1369390    2022-01-08               8           2022
# 31470      275501   1369391    2022-01-08               8           2022
# 31471      275502   1369392    2022-01-08               8           2022
#
#         TIME TIME_OF_DAY AIRPORT_ID                              AIRPORT  \
# 0        NaN         Day       KSAT                     SAN ANTONIO INTL
# 1        NaN        Dawn       KMCI                     KANSAS CITY INTL
# 2        NaN         NaN       KMCI                     KANSAS CITY INTL
# 3        NaN         Day       KDFW          DALLAS/FORT WORTH INTL ARPT
# 4        NaN         Day       KSJC  NORMAN Y. MINETA SAN JOSE INTL ARPT
# ...      ...         ...        ...                                  ...
# 31467   9:10         Day       KHPN              WESTCHESTER COUNTY ARPT
# 31468    NaN         NaN       KJFK                  JOHN F KENNEDY INTL
# 31469  21:04         NaN       KCKB     NORTH CENTRAL WEST VIRGINIA ARPT
# 31470   8:14         Day       KCMH        JOHN GLENN COLUMBUS INTL ARPT
# 31471  17:40         Day       KGTR             GOLDEN TRIANGLE REGIONAL
#
#         LATITUDE  ...  REMAINS_COLLECTED REMAINS_SENT   WARNED       NUM_SEEN  \
# 0      29.533690  ...                  0            0       No              1
# 1      39.297610  ...                  0            0      Yes  More than 100
# 2      39.297610  ...                  0            0  Unknown            NaN
# 3      32.895950  ...                  0            0       No         02-Oct
# 4      37.361860  ...                  0            0      Yes              1
# ...          ...  ...                ...          ...      ...            ...
# 31467  41.066960  ...                  1            0      Yes              1
# 31468  40.639750  ...                  1            0  Unknown            NaN
# 31469  39.296640  ...                  0            0  Unknown            NaN
# 31470  39.996947  ...                  0            0  Unknown            NaN
# 31471  33.450200  ...                  0            0  Unknown            NaN
#
#       NUM_STRUCK    SIZE                                           COMMENTS  \
# 0              1  Medium      SOURCE = FAA FROM 3830 /Legacy Record=100006/
# 1         11-100  Medium  THIS MAY BE DUPL STRIKE FOR AIR MIDWEST, BUT T...
# 2              1  Medium                             /Legacy Record=100008/
# 3           2-10   Small                             /Legacy Record=100009/
# 4              1   Small  A/C = FAIRCHILD METRO II (5/8/14 UPDATED A/C) ...
# ...          ...     ...                                                ...
# 31467        NaN  Medium                                                NaN
# 31468          1   Small                                                NaN
# 31469          1   Small                                                NaN
# 31470       2-10     NaN                                                NaN
# 31471          1     NaN                                                NaN
#
#                      SOURCE                    PERSON          LUPDATE
# 0                     Other                     Pilot  21/11/1997 0:00
# 1           FAA Form 5200-7                       NaN  13/05/1998 0:00
# 2      Air Transport Report  Air Transport Operations  20/12/2007 0:00
# 3           FAA Form 5200-7                     Pilot  21/01/1999 0:00
# 4           FAA Form 5200-7                       NaN  08/05/2014 0:00
# ...                     ...                       ...              ...
# 31467     FAA Form 5200-7-E        Airport Operations  03/02/2023 0:00
# 31468     FAA Form 5200-7-E             Carcass Found  03/02/2023 0:00
# 31469                   MOR                     Tower  03/02/2023 0:00
# 31470                   MOR                     Tower  03/02/2023 0:00
# 31471                   MOR                     Tower  03/02/2023 0:00
#
# [263880 rows x 84 columns]

# %% [markdown]
# #### Task 3.7
#
# There are columns that specify if a certain part of the aircraft was struck. Their values are either `0` or `1`.\
# For example, `STR_WINDSHLD`=1 means that the aircraft was struck on its windshield.\
# All columns indicating a strike begin with `STR_`.
#
# You need to add a column that accumlates the number of strikes for each aircraft (each row in the dataframe).\
# Name the new column: `total_struck`\
# Print the mean number of strikes using this function: `all_strikes["STR_total"].mean()`

# %%
all_strikes['total_struck'] = all_strikes.filter(like='STR_').sum(axis=1)
mean_num_strikes = all_strikes['total_struck'].mean()
mean_num_strikes
# Out:
# 0.8371987266939518

# %% [markdown]
# #### Task 3.8
#
# Now, find all columns that indicate a certain part of the aircraft was damaged (hint: these columns begin with `DAM`).\
# Add a column named: `total_damaged` that indicates the total damaged parts of an aircraft.\
# Print the mean damage.

# %%
damaged_columns = all_strikes.filter(like="DAM_")
all_strikes["total_damaged"] = damaged_columns.sum(axis=1)
mean_damage = all_strikes["total_damaged"].mean()
mean_damage
# Out:
# 0.08663786569652873

# %% [markdown]
# ## CHECKPOINT (not obligatory)

# %% [markdown]
# If you are not sure that you performed the previous tasks correctly, you can now import the pickle: `strikes_checkpoint` and continue your work with it.\
# Note: the file is compressed with zip, you need to unzip it first.

# %%
import pandas as pd
# all_strikes = pd.read_pickle('strikes_checkpoint')

# %%
all_strikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 263880 entries, 0 to 31471
# Data columns (total 86 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         263880 non-null  int64
#  1   INDEX_NR           263880 non-null  int64
#  2   INCIDENT_DATE      263880 non-null  datetime64[ns]
#  3   INCIDENT_MONTH     263880 non-null  int64
#  4   INCIDENT_YEAR      263880 non-null  int64
#  5   TIME               141976 non-null  object
#  6   TIME_OF_DAY        154652 non-null  object
#  7   AIRPORT_ID         263878 non-null  object
#  8   AIRPORT            263880 non-null  object
#  9   LATITUDE           231357 non-null  float64
#  10  LONGITUDE          231357 non-null  float64
#  11  RUNWAY             199566 non-null  object
#  12  STATE              231358 non-null  object
#  13  FAAREGION          231358 non-null  object
#  14  OPID               263871 non-null  object
#  15  OPERATOR           263880 non-null  object
#  16  REG                157824 non-null  object
#  17  FLT                116545 non-null  object
#  18  AIRCRAFT           263880 non-null  object
#  19  AMA                189863 non-null  object
#  20  AMO                177993 non-null  object
#  21  EMA                176576 non-null  float64
#  22  EMO                172767 non-null  object
#  23  AC_CLASS           190979 non-null  object
#  24  AC_MASS            190648 non-null  float64
#  25  TYPE_ENG           190231 non-null  object
#  26  NUM_ENGS           190439 non-null  float64
#  27  ENG_1_POS          189756 non-null  float64
#  28  ENG_2_POS          177474 non-null  float64
#  29  PHASE_OF_FLIGHT    164159 non-null  object
#  30  HEIGHT             138608 non-null  float64
#  31  SPEED              88946 non-null   float64
#  32  DISTANCE           169693 non-null  float64
#  33  SKY                129763 non-null  object
#  34  PRECIPITATION      125083 non-null  object
#  35  INGESTED_OTHER     263880 non-null  int64
#  36  INDICATED_DAMAGE   263880 non-null  int64
#  37  DAMAGE_LEVEL       173949 non-null  object
#  38  STR_RAD            263880 non-null  int64
#  39  DAM_RAD            263880 non-null  int64
#  40  STR_WINDSHLD       263880 non-null  int64
#  41  DAM_WINDSHLD       263880 non-null  int64
#  42  STR_NOSE           263880 non-null  int64
#  43  DAM_NOSE           263880 non-null  int64
#  44  STR_ENG1           263880 non-null  int64
#  45  DAM_ENG1           263880 non-null  int64
#  46  ING_ENG1           263880 non-null  int64
#  47  STR_ENG2           263880 non-null  int64
#  48  DAM_ENG2           263880 non-null  int64
#  49  ING_ENG2           263880 non-null  int64
#  50  STR_ENG3           263880 non-null  int64
#  51  DAM_ENG3           263880 non-null  int64
#  52  ING_ENG3           263880 non-null  int64
#  53  STR_ENG4           263880 non-null  int64
#  54  DAM_ENG4           263880 non-null  int64
#  55  ING_ENG4           263880 non-null  int64
#  56  STR_PROP           263880 non-null  int64
#  57  DAM_PROP           263880 non-null  int64
#  58  STR_WING_ROT       263880 non-null  int64
#  59  DAM_WING_ROT       263880 non-null  int64
#  60  STR_FUSE           263880 non-null  int64
#  61  DAM_FUSE           263880 non-null  int64
#  62  STR_LG             263880 non-null  int64
#  63  DAM_LG             263880 non-null  int64
#  64  STR_TAIL           263880 non-null  int64
#  65  DAM_TAIL           263880 non-null  int64
#  66  STR_LGHTS          263880 non-null  int64
#  67  DAM_LGHTS          263880 non-null  int64
#  68  STR_OTHER          263880 non-null  int64
#  69  DAM_OTHER          263880 non-null  int64
#  70  EFFECT             135501 non-null  object
#  71  SPECIES_ID         263879 non-null  object
#  72  SPECIES            263879 non-null  object
#  73  REMARKS            240809 non-null  object
#  74  REMAINS_COLLECTED  263880 non-null  int64
#  75  REMAINS_SENT       263880 non-null  int64
#  76  WARNED             263880 non-null  object
#  77  NUM_SEEN           87743 non-null   object
#  78  NUM_STRUCK         263263 non-null  object
#  79  SIZE               243037 non-null  object
#  80  COMMENTS           216251 non-null  object
#  81  SOURCE             263880 non-null  object
#  82  PERSON             242718 non-null  object
#  83  LUPDATE            263880 non-null  object
#  84  total_struck       263880 non-null  int64
#  85  total_damaged      263880 non-null  int64
# dtypes: datetime64[ns](1), float64(10), int64(42), object(33)
# memory usage: 175.2+ MB

# %% [markdown]
# ## Task 4 - Filtering

# %%
all_strikes['INCIDENT_DATE']=pd.to_datetime(all_strikes['INCIDENT_DATE'])
all_strikes['INCIDENT_DATE']
# Out:
# 0       1991-06-05
# 1       1993-05-11
# 2       1995-02-07
# 3       1990-09-19
# 4       1992-03-05
#            ...
# 31467   2022-11-23
# 31468   2022-11-24
# 31469   2022-01-08
# 31470   2022-01-08
# 31471   2022-01-08
# Name: INCIDENT_DATE, Length: 263880, dtype: datetime64[ns]

# %% [markdown]
# #### Task 4.1
#
# Create a dataframe that contains only data from aircraft of type `A-320` from `INCIDENT_DATE` 1.1.2022 and onward.\
# How many rows does your dataframe contain?

# %%
all_strikes['AIRCRAFT']
all_strikes[all_strikes['AIRCRAFT']=='A-320']
# Out:
#        Unnamed: 0  INDEX_NR INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 64             64    608320    1992-11-29              11           1992
# 100           100    608245    1996-01-07               7           1996
# 101           101    608246    1996-01-07               7           1996
# 651           651    608935    1996-10-28              10           1996
# 824           824    609376    1996-07-22               7           1996
# ...           ...       ...           ...             ...            ...
# 31415      275446   1369303    2022-07-28               7           2022
# 31431      275462   1369339    2022-07-31               7           2022
# 31459      275490   1369379    2022-11-22              11           2022
# 31460      275491   1369380    2022-11-22              11           2022
# 31469      275500   1369390    2022-01-08               8           2022
#
#         TIME TIME_OF_DAY AIRPORT_ID                           AIRPORT  \
# 64       NaN         Day       KCMH     JOHN GLENN COLUMBUS INTL ARPT
# 100      NaN         NaN       KIAD       WASHINGTON DULLES INTL ARPT
# 101      NaN         NaN       KLGA                   LA GUARDIA ARPT
# 651      NaN         NaN       KLAX                  LOS ANGELES INTL
# 824      NaN         NaN       KIAD       WASHINGTON DULLES INTL ARPT
# ...      ...         ...        ...                               ...
# 31415   6:57         NaN       KSMF                   SACRAMENTO INTL
# 31431  16:43         Day       KMCO                      ORLANDO INTL
# 31459  21:20         NaN       ZZZZ                           UNKNOWN
# 31460    NaN         Day       KJFK               JOHN F KENNEDY INTL
# 31469  21:04         NaN       KCKB  NORTH CENTRAL WEST VIRGINIA ARPT
#
#         LATITUDE  ...   WARNED NUM_SEEN NUM_STRUCK    SIZE  \
# 64     39.996947  ...      Yes      NaN       2-10   Small
# 100    38.944530  ...  Unknown      NaN          1  Medium
# 101    40.777240  ...  Unknown      NaN          1  Medium
# 651    33.942540  ...  Unknown      NaN          1  Medium
# 824    38.944530  ...  Unknown      NaN          1  Medium
# ...          ...  ...      ...      ...        ...     ...
# 31415  38.695420  ...  Unknown      NaN          1     NaN
# 31431  28.428890  ...  Unknown      NaN          1     NaN
# 31459        NaN  ...  Unknown      NaN          1   Small
# 31460  40.639750  ...      Yes      NaN          1  Medium
# 31469  39.296640  ...  Unknown      NaN          1   Small
#
#                       COMMENTS                SOURCE  \
# 64      /Legacy Record=100079/       FAA Form 5200-7
# 100     /Legacy Record=100004/  Air Transport Report
# 101     /Legacy Record=100005/  Air Transport Report
# 651     /Legacy Record=100695/  Air Transport Report
# 824     /Legacy Record=101137/  Air Transport Report
# ...                        ...                   ...
# 31415                      NaN                   MOR
# 31431                      NaN                   MOR
# 31459                      NaN     FAA Form 5200-7-E
# 31460                      NaN     FAA Form 5200-7-E
# 31469                      NaN                   MOR
#
#                          PERSON          LUPDATE total_struck total_damaged
# 64                          NaN  31/07/1998 0:00            1             0
# 100    Air Transport Operations  20/12/2007 0:00            1             0
# 101    Air Transport Operations  20/12/2007 0:00            2             1
# 651    Air Transport Operations  20/12/2007 0:00            1             0
# 824    Air Transport Operations  20/12/2007 0:00            1             0
# ...                         ...              ...          ...           ...
# 31415                     Tower  02/02/2023 0:00            1             0
# 31431                     Tower  02/02/2023 0:00            1             0
# 31459        Airport Operations  03/02/2023 0:00            1             0
# 31460        Airport Operations  03/02/2023 0:00            1             0
# 31469                     Tower  03/02/2023 0:00            1             0
#
# [12659 rows x 86 columns]

# %% [markdown]
# #### Task 4.2
#
# Create a dataframe the contains only data where the number `DMG_total`  (the total damage) is 5 or more.\
# Print the number of rows in the dataframe.

# %%
all_strikes['total_damaged']
all_strikes[all_strikes['total_damaged']>=5]
# Out:
#         Unnamed: 0  INDEX_NR INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 2347          2347    610926    1990-12-23              12           1990
# 3205          3205    611885    1994-04-13               4           1994
# 4116          4116    613486    1994-11-03               3           1994
# 5475          5475    615070    1994-12-18              12           1994
# 6858          6858    616086    1991-09-11              11           1991
# ...            ...       ...           ...             ...            ...
# 232253      273897   1365586    2003-10-22              10           2003
# 232286      274644   1367661    2014-12-11              11           2014
# 232302      274662   1367679    2018-07-11              11           2018
# 7785        241093   1159239    2021-09-29               9           2021
# 20152       258883   1280700    2021-06-09               9           2021
#
#          TIME TIME_OF_DAY AIRPORT_ID                                 AIRPORT  \
# 2347     7:10        Dawn       KMSY   LOUIE ARMSTRONG NEW ORLEANS INTL ARPT
# 3205      NaN        Dawn        H2O                            REMOTE_WATER
# 4116      NaN       Night       KCLL                EASTERWOOD FIELD AIRPORT
# 5475      NaN       Night       KCTJ  WEST GEORGIA REGNL ARPT-O V GRAY FIELD
# 6858    17:01         Day       KJFK                     JOHN F KENNEDY INTL
# ...       ...         ...        ...                                     ...
# 232253  11:26         Day       ZZZZ                                 UNKNOWN
# 232286  18:18         Day       KMCI                        KANSAS CITY INTL
# 232302  20:00       Night       KSLC                     SALT LAKE CITY INTL
# 7785    20:15       Night        I42                 PAOLI MUNICIPAL AIRPORT
# 20152   22:46       Night       KOAJ                          ALBERT J ELLIS
#
#          LATITUDE  ...   WARNED NUM_SEEN NUM_STRUCK    SIZE  \
# 2347    29.993390  ...      Yes   11-100     11-100  Medium
# 3205          NaN  ...  Unknown        1          1   Large
# 4116    30.588590  ...       No   11-100     11-100   Large
# 5475    33.631030  ...  Unknown   02-Oct       2-10   Large
# 6858    40.639750  ...       No   11-100       2-10   Large
# ...           ...  ...      ...      ...        ...     ...
# 232253        NaN  ...  Unknown        1          1   Large
# 232286  39.297610  ...      Yes   11-100       2-10   Large
# 232302  40.788390  ...      Yes      NaN       2-10   Large
# 7785    38.584804  ...  Unknown        1          1   Large
# 20152   34.829160  ...       No   02-Oct       2-10   Small
#
#                                                  COMMENTS             SOURCE  \
# 2347    SOURCE = 5200-7 & FAA TECH CENTER BIRD INGESTI...           Multiple
# 3205    SOURCE = AIRCRAFT ACCIDENT/INCIDENT NOTICE & P...              Other
# 4116    SOURCE =  AC INCIDENT & TWO 5200-7 REPTS. /Leg...           Multiple
# 5475    SOURCE = NTSB, AAIPN AND 5200-7 (OBTAINED BY P...           Multiple
# 6858    SOURCE = 5200-7, AC INCIDENT REPT, DAILY ALERT...           Multiple
# ...                                                   ...                ...
# 232253                                                NaN           Multiple
# 232286                             REVISED SPECIES PER RD           Multiple
# 232302                             REVISED SPECIES PER RD           Multiple
# 7785    The airplane is out for a year or so, if the i...  FAA Form 5200-7-E
# 20152   EOF OTHER REPORTED AS Bird strike reported aft...  FAA Form 5200-7-E
#
#                     PERSON          LUPDATE total_struck total_damaged
# 2347    Airport Operations  23/09/2003 0:00            5             5
# 3205    Airport Operations  04/08/2004 0:00            5             5
# 4116                 Pilot  15/03/1999 0:00            9             7
# 5475                 Pilot  04/08/2004 0:00           10            10
# 6858                 Tower  08/04/2015 0:00            5             5
# ...                    ...              ...          ...           ...
# 232253               Other  23/01/2023 0:00            1             5
# 232286               Pilot  26/01/2023 0:00            6             6
# 232302  Airport Operations  26/01/2023 0:00            7             6
# 7785                 Pilot  25/10/2021 0:00            5             5
# 20152   Airport Operations  11/08/2022 0:00            5             5
#
# [137 rows x 86 columns]

# %% [markdown]
# ## Task 5 - Data Analysis

# %% [markdown]
# #### Task 5.1

# %% [markdown]
# Each reported incident is a row in the dataframe.\
# Which airports (column `AIRPORT`) reported the most incidents?\
# Present the names of the 10 airports who reported the most incidents.\
# Note: You will see that the most common airport is `UNKNOWN`. Omit it and look at the 10 airports with a known name (for example: `MEMPHIS INTL` is one of these 10 airports)

# %%
all_strikes.groupby('AIRPORT')['total_damaged'].sum()
all_strikes.sort_values('AIRPORT',ascending=False).head(10)
# Out:
#         Unnamed: 0  INDEX_NR INCIDENT_DATE  INCIDENT_MONTH  INCIDENT_YEAR  \
# 136956      136956    754753    2014-06-16               6           2014
# 4563          4563    613469    1992-03-07               7           1992
# 105540      105540    722126    2011-06-24               6           2011
# 230863      269150   1345152    2010-07-18               7           2010
# 116032      116032    732919    2012-05-07               7           2012
# 18192       254390   1259386    2022-06-06               6           2022
# 63838        63838    679091    2006-02-08               8           2006
# 230446      268680   1344646    2016-06-19               6           2016
# 139229      139229    756903    2014-07-14               7           2014
# 24879       266806   1339747    2022-10-17              10           2022
#
#          TIME TIME_OF_DAY AIRPORT_ID AIRPORT   LATITUDE  ...   WARNED  \
# 136956  12:50         Day       LSZH  ZURICH  47.464722  ...  Unknown
# 4563      NaN         Day       LSZH  ZURICH  47.464722  ...       No
# 105540  10:35         Day       LSZH  ZURICH  47.464722  ...       No
# 230863  10:55         Day       LSZH  ZURICH  47.464722  ...  Unknown
# 116032   8:50         Day       LSZH  ZURICH  47.464722  ...  Unknown
# 18192     NaN         Day       LSZH  ZURICH  47.464722  ...       No
# 63838     NaN         NaN       LSZH  ZURICH  47.464722  ...  Unknown
# 230446  11:00         Day       LSZH  ZURICH  47.464722  ...  Unknown
# 139229  11:08         Day       LSZH  ZURICH  47.464722  ...       No
# 24879   10:21         Day       LSZH  ZURICH  47.464722  ...  Unknown
#
#        NUM_SEEN NUM_STRUCK    SIZE  \
# 136956      NaN          1   Small
# 4563     02-Oct          1  Medium
# 105540        1          1   Small
# 230863      NaN          1   Small
# 116032      NaN          1     NaN
# 18192         1          1  Medium
# 63838       NaN       2-10   Small
# 230446        1          1     NaN
# 139229   02-Oct          1   Small
# 24879       NaN          1   Small
#
#                                                  COMMENTS  \
# 136956  SOURCE = TWO 5200-7 (2014-6-16-133421, R1) /Le...
# 4563    UPDATED 5/13/09 CHANGED DATE TO 3 FROM 30 AND ...
# 105540            2011-6-24-153354 /Legacy Record=313252/
# 230863                                                NaN
# 116032  SOURCE = TWO 5200-7 (2012-7-10-161726 & 7-17-1...
# 18192                                                 NaN
# 63838                              /Legacy Record=240907/
# 230446                                                NaN
# 139229            2014-7-15-154124 /Legacy Record=349127/
# 24879                                                 NaN
#
#                       SOURCE                    PERSON          LUPDATE  \
# 136956     FAA Form 5200-7-E  Air Transport Operations  23/10/2014 0:00
# 4563         FAA Form 5200-7                     Pilot  13/05/2009 0:00
# 105540     FAA Form 5200-7-E  Air Transport Operations  21/07/2011 0:00
# 230863     FAA Form 5200-7-E                     Pilot  30/11/2022 0:00
# 116032     FAA Form 5200-7-E                     Other  19/09/2012 0:00
# 18192      FAA Form 5200-7-E                     Pilot  23/06/2022 0:00
# 63838   Air Transport Report  Air Transport Operations  01/11/2006 0:00
# 230446     FAA Form 5200-7-E                     Pilot  30/11/2022 0:00
# 139229     FAA Form 5200-7-E                     Pilot  10/12/2014 0:00
# 24879      FAA Form 5200-7-E        Airport Operations  01/11/2022 0:00
#
#        total_struck total_damaged
# 136956            2             0
# 4563              1             0
# 105540            1             0
# 230863            1             0
# 116032            1             1
# 18192             1             0
# 63838             1             0
# 230446            1             0
# 139229            2             0
# 24879             1             0
#
# [10 rows x 86 columns]

# %% [markdown]
# #### Task 5.2
# Create a dataframe that contains only the 10 airports that reported the most incidents.\
# Print the percentage of incidents (out of the total amount of incidents) reported by these 10 airports

# %%
airport = all_strikes.groupby('AIRPORT')['total_damaged'].sum()
top_10 = airport.sort_values(ascending=False).head(10)
total = airport.sum()
per_incidents = (top_10 / total) * 100
per_incidents
# Out:
# AIRPORT
# UNKNOWN                        19.018459
# SACRAMENTO INTL                 2.366372
# SALT LAKE CITY INTL             1.802117
# JOHN F KENNEDY INTL             1.434695
# ORLANDO INTL                    1.299099
# DALLAS/FORT WORTH INTL ARPT     1.272855
# CHICAGO O'HARE INTL ARPT        1.215992
# DENVER INTL AIRPORT             1.062899
# LA GUARDIA ARPT                 1.041029
# MEMPHIS INTL                    0.949173
# Name: total_damaged, dtype: float64

# %% [markdown]
# #### Task 5.3
#
# When do most incidents occur?
# Create a table that displays the average number of strikes (as indicated by the column `STR_total`) and the average damage (column `DMG_total`) at different times during the day (`TIME_OF_DAY`)

# %%
 average = all_strikes.groupby('TIME_OF_DAY').agg({'total_struck': 'mean', 'total_damaged': 'mean'})
 average
# Out:
#              total_struck  total_damaged
# TIME_OF_DAY
# Dawn             1.166787       0.111312
# Day              1.126167       0.110161
# Dusk             1.262891       0.162080
# Night            1.180346       0.143127

# %% [markdown]
# #### Task 5.4
#
# Do warnings help?\
# Create a table showing the total number of strikes (`STR_total`) when a warning was issued or not issued (column `WARNED`).\
# Omit rows where it is unknown whether or not a warning was issued.

# %%
all_strikes.groupby('WARNED')['total_struck'].sum()
# Out:
# WARNED
# No         71210
# Unknown    94522
# Yes        55188
# Name: total_struck, dtype: int64

# %% [markdown]
# #### Task 5.5
# Who reports the incidents most often? Use the column `PERSON` to find out.

# %%
 all_strikes['PERSON'].value_counts()
# Out:
# Carcass Found               70781
# Airport Operations          58114
# Pilot                       48015
# Air Transport Operations    32564
# Tower                       27279
# Other                        5965
# Name: PERSON, dtype: int64

# %% [markdown]
# #### Task 5.6
#
# Who reports the incidents most often **when there is damage to the aircraft**?
#
# Create a table that displays the reporting person (`PERSON`) and the total damage (`DMG_total`) and total strikes (`STR_total`)

# %%
all_strikes.groupby('PERSON').agg({'total_damaged':'sum','total_struck':'sum'}).reset_index()
# Out:
#                      PERSON  total_damaged  total_struck
# 0  Air Transport Operations           3701         36624
# 1        Airport Operations           4354         66020
# 2             Carcass Found              0            42
# 3                     Other           1808          6882
# 4                     Pilot           7297         61151
# 5                     Tower           2490         27689

# %% [markdown]
# ## Task 6 - Data Visualization

# %% [markdown]
# #### Task 6.1
#
# Present **one** histogram plot that contains **two** distributions: the `SPEED` when there was and wasn't a warning (column `WARNED`)\
# Note:
# * Remove outliers: that is, remove the two rows where the speed is higher than 1000 mph.
# * Do not display incidents with an Unknown warning.
# * Do not use more than 20 bins (see [histplot documentation](https://seaborn.pydata.org/generated/seaborn.histplot.html) )

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
DATA=all_strikes[all_strikes['SPEED']<=1000]
sns.histplot(x='SPEED',hue='WARNED',bins=20,data=DATA,common_norm=False)
# Out:
# <Axes: xlabel='SPEED', ylabel='Count'>

# %% [markdown]
# #### Task 6.2
#
# Present a figure that compares the `DMG_Total` in 2017-2022 (`INCIDENT_YEAR`), for different warnings (`WARNED`) types.

# %%
year=all_strikes[all_strikes['INCIDENT_YEAR'].between(2017,2022)]
group_data=year.groupby('WARNED')['total_damaged'].sum().reset_index()
plt.bar(group_data['WARNED'],group_data['total_damaged'])
plt.xlabel('WARNED')
plt.ylabel('Total Damaged')
plt.title('DMG total in 2017-2022 for different warning types')
# Out:
# Text(0.5, 1.0, 'DMG total in 2017-2022 for different warning types')

# %% [markdown]
# #### Task 6.3
#
# Create a figure that compares and displays **how many** strikes (`STR_total`) occurred in different phases of the flight (`PHASE_OF_FLIGHT`). The figure should only present cases where there are 8 or more total strikes (`STR_total`). Make sure the categories on the x-axis are readable.

# %%
DF4=all_strikes[all_strikes['total_struck']>=8]
phase_counts=DF4.groupby('PHASE_OF_FLIGHT')['total_struck'].count()
plt.bar(phase_counts.index,phase_counts)
plt.xlabel('Phase of Flight')
plt.ylabel('Number Of Strikes')
# plt.title('Comarison of Strikes in Diff Phases of Flight')
plt.show()

# %% [markdown]
# #### Task 6.4
#
# Create a figure that displays the correlation between the `HEIGHT` and the total strikes (`STR_total`)

# %%
plt.scatter(all_strikes['HEIGHT'],all_strikes['total_struck'])
plt.xlabel('HEIGHT')
plt.ylabel('total_struck')
plt.title=('Correlation Between Height and STR_total')

# %% [markdown]
# #### Task 6.5
#
# Create a figure that shows the **median** speed in different times of the day (`SPEED`, `TIME_OF_DAY`).
# Do not show cases where the speed is higher than 500 mph.

# %%
all_strikes=all_strikes[all_strikes['SPEED']<=500]
median=all_strikes.groupby('TIME_OF_DAY')['SPEED'].median()
median.plot(kind='bar')
plt.xlabel('TIME OF DAY')
plt.ylabel('SPEED')
plt.title=('Median SPEED in diff TIME OF DAY')
plt.show()

# %% [markdown]
# ## Task 7 - Statistics

# %% [markdown]
# #### Task 7.1 (2 points):
#
# Which type of t-test should be used to determine if there is a statistical difference between the number of strikes (`STR_total`) when there was\wasn't a warning (`WARNED=Yes\No`)

# %%
from statsmodels.stats.weightstats import ttest_ind

# %%
data_first=all_strikes.loc[all_strikes['WARNED']=='Yes','total_struck']

# %%
data_second=all_strikes.loc[all_strikes['WARNED']=='No','total_struck']

# %%
ttest_ind(data_first, data_second)
# Out:
# (1.1543207511029707, 0.24837261460738475, 70325.0)

# %% [markdown]
# #### Task 7.2
#
# Apply the test you suggested in the previous task.

# %% [markdown]
# #### Task 7.3
#
# What do the results tell us?
# Briefly interpret the results.

# %% [markdown]
# #### Task 7.4
#
# Which type of test should be used to determine whether the proportion of total damage (`DMG_total`) out of all the total strikes (`STR_total`), is constant in all `INCIDENT_YEAR`?

# %% [markdown]
# T Type test is uded.

# %% [markdown]
# #### Task 7.5
#
# Apply the test you suggested in the previous task.

# %% [markdown]
# #### Task 7.6
#
# Briefly interpret the results.

# %% [markdown]
# ## Task 8 - Web scraping

# %% [markdown]
# #### Task 8.1
# How much do airplanes cost on ebay?
#
# Analyze this link: https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=airplanes&_sacat=0&LH_TitleDesc=0&_odkw=planes&_osacat=0&_sop=12&LH_PrefLoc=2
#
# Create a list of the **names** of all items sold on this page. No need to scroll to the next pages.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
url='https://www.ebay.com/sch/i.html?_from=R40&_trksid=p2334524.m570.l1313&_nkw=airplanes&_sacat=0&LH_TitleDesc=0&_odkw=planes&_osacat=0&_sop=12&LH_PrefLoc=2'
response=requests.get(url)
soup = bs(response.text, 'html.parser')
item_names = [item.text for item in soup.find_all(class_="s-item__title")]
item_names
# Out:
# ['Shop on eBay',
#  'Eflite umx radian',
#  'Midwest Super Stinker 11-260 Kit 27% Scale RC Biplane *Plse read Description ',
#  'Kid Xmas Gift EPP Foam SU-35 Model Plane Toy Remote Control Airplane RC Glider',
#  'Great Planes Cherokee .40-.46 GP/EP ARF 60 GPMA1033 Airplanes ARF Sport',
#  'HobbyZone Carbon Cub S2 BNF Basic Airplane (HBZ32500)',
#  'MiniArt 48001 P-47D-25RE Thunderbolt Advanced Kit 1/48',
#  'ICM 48195 Japanese Heavy Bomber Ki-21-Ib Sally 1/48',
#  'HobbyZone HBZ44500 Sport Cub BNF Basic',
#  'Great Planes Cherokee .40-.46 GP/EP ARF 60 GPMA1033 Airplanes ARF Sport',
#  'Phoenix Model Edge 540 .46-.55 GP/EP ARF 55.5 PMMA0360 Airplanes ARF Scale',
#  'Kid Xmas Gift EPP Foam SU-35 Model Plane Toy Remote Control Airplane RC Glider',
#  'Phoenix Model F4U Corsair .46-.55 GP/EP ARF 58.5 PMMA1605 Airplanes ARF Scale',
#  'VOLANTEXRC 4-CH Spitfire One Key Remote Control Airplane with Xpilot Stabilizer',
#  'HobbyZone RC Airplane Apprentice STOL S 700 BNF Basic   with AS3X/SAFE',
#  'Stealth RC Airplane 2.4Ghz Raptor Toy Plane Adult Kids Remote Control Motor 2023',
#  'Calibre Wings 1:72 F-14A Tomcat USN Top Gun Maverick and Goose',
#  'InAir E-Z Build Model Kit - YF-23 Black Widow - 1:72 Scale',
#  'Flair RC Glider Kit',
#  'New Remote Control Wireless Airplane Toy Model RC Airplanes Jet Fighter f',
#  'Die Cast LOT OF 15 Commercial Airliner  Airplanes Some Vintage Lin toy,Schabak!!',
#  'CEMxxx 01 "Doohickus Mk. I" Lightforming tool For Scale Models 1/72 and 1/48',
#  'HobbyZone RC Airplane AeroScout S 2 1.1m BNF Basic   HBZ385001 Airplanes Bind',
#  'Phoenix Model Edge 540 .46-.55 GP/EP ARF 55.5 PMMA0360 Airplanes ARF Scale',
#  'Great Planes Cherokee .40-.46 GP/EP ARF 60 GPMA1033 Airplanes ARF Sport',
#  'Very Rare Balsa Built Boeing XL-15 3ch 62" Jaitec 35 RTF RC Aircraft Plane',
#  'Vintage Flair Legionaire Nieuport 17 Rc Biplane Kit',
#  'Smithsonian P-51 Mustang Rubber Band Powered Flyer',
#  'FRSKY TARANIS X9E TRANSMITTER RUNNING OPEN TX ON MODE 1 EXCELLENT CONDITION',
#  'Piper J-3 Cub Remote Control Airplane, 2 Channel Glide Toy For Adults, Kids',
#  'Airsail De Havilland Chipmunk R/C Scale Aircraft',
#  'SIG Kadet Senior Balsa Wood RC Airplane Kit 78" Wingspan #RC-58',
#  'Tamiya 1/48 Lockheed Martin F-35A Lightning II TAM61124 Plastic Models Airplane',
#  'P-17 RC Model Airplane With Snoopy As Pilot Over 3 Foot Wingspan',
#  'SkyAngel F-86 Sabre 35mm EDF EPO 2.4GHz Micro RC Model Aircraft Plane',
#  'Academy 1/72 ROKAF KF-21 Boramae Korea Air-force Aircraft Hobby Model Kit #12585',
#  'Park Flite Cessna 182 Skylane RTF 2.4Ghz - Blue: Ready To Fly RC Plane TGP0355B',
#  'US Airplanes F22 Jet Remote Control Fighter Night Flight RTF 2.4gHz Plane Model',
#  'Phoenix Model F4U Corsair .46-.55 GP/EP ARF 58.5 PMMA1605 Airplanes ARF Scale',
#  'VOLANTEXRC 4-CH Spitfire One Key Remote Control Airplane with Xpilot Stabilizer',
#  'RC Airplanes F22 Jet Remote Control Fighter Night Flight RTF 2.4gHz Plane Model',
#  'Remote Control Graupner MC 12',
#  'Carl Goldberg Models Gentle Lady Rc Glider Kit',
#  'Hallmark Keepsake Ornament - you pick',
#  'MultiPlex EasyStar Radio Controlled RC Model Aircraft Plane Trainer',
#  'Cambrian Models Elan 100 Rc Glider',
#  'Cessna 177 52" Wingspan R/C Airplane Kit Laser Cut Balsa & Ply Short Kit',
#  'HobbyZone RC Airplane Apprentice STOL S 700 BNF Basic   with AS3X/SAFE',
#  '3 Pack Airplane Launcher Toy Foam Glider Planes for Kids with 2 Flight Mode',
#  'HobbyZone Super Cub 3ch AS3X & SAFE BNF RC Model Aircraft Plane Trainer',
#  'Royal Aircraft Kit: Partenavia P68 Victor twin balsa kit New in Box - Rare',
#  'MultiPlex Funcub 1400mm High Wing Trainer ELAPOR Foam RC Model Aircraft Plane',
#  'Cessna 177 Cardinal Radio control airplane ARC',
#  'Rc EFLITE UMX MIG 15 DF AS3X RC PLANE BOXED Jet Plane',
#  'Pou Du Ciel 44" Wingspan R/C Airplane Kit Laser Cut Balsa & Ply Short Kit',
#  'RC model kit Ben Buckle Hepcat',
#  'Offer antique Webra diesel',
#  'Rocket City Specialties SWIVEL LINK OFFSET R/C Model Airplane   4/40 AND 8/32',
#  'Offer antique Webra diesel',
#  'Toy Airplane Games Styrofoam Throw Planes for Kids Gift Set of 2 Various Colors',
#  'FLAIR "SUNRISE" GLIDER MODEL KIT 98.5" WINGSPAN NEW IN THE BOX RARE TO FIND',
#  'E-FLITE Carbon-Z T-28 Trojan 2.0m BNF TOUCH UP PAINT GREAT TO HAVE GOOD FEEDBACK',
#  'SNOOPEY Sticker',
#  'RC Airplane RAPTOR H650 sea land air 490 mm wingspan 2.4GHz 6CH Warbird Red',
#  'Vintage O. S. Engines Max 40 R/C Piston Pin Wrist Pin New Old Stock HTF Rare',
#  'Hobby Boss 1/72 F-22 Raptor Plastic Model Kit 80210 New In Box',
#  'Inflatable Air Travel Pillow Airplane Office Nap Rest Neck Head Chin Cushion',
#  'Stealth RC Airplane 2.4Ghz Raptor Toy Plane Adult Kids Remote Control Motor 2023',
#  '1/48 CEM48008 A-26K Replacement 8 gun nose (for ICM kit #48279)',
#  'Revell 1/32 scale Dassault  Mirage III brand new kit ( bag kit ) read note',
#  'Airfix A04066 Messerschmitt Me410A-1/U2 & U4',
#  'Dora Wings 48054 1/48 Republic P-47C Thunderbolt with Ferry tank',
#  'Kinetic K48142 1/48 K48142 IA-58 Pucara Royal Air Force Model Kit',
#  'VOLANTEX WWII P51 4CH Fighter RC Airplanes 2.4G Remote 3D 6Axis Stunt Glider Toy',
#  'MiniArt 48009 P-47D-25RE Thunderbolt Basic Kit 1/48',
#  "Guillow's Lancer Flying Airplane Model Kit Easy Balsa Kit Rubber Powered 604 NEW",
#  'UC-64A Norseman 1/72 Revell 04291\xa0 AirPlane Model Kit NIB Sealed',
#  'Diecast USAF Model Stealth Fighter Jet Airplane Toy Set SR-71, B-2, F-117, F-22',
#  'Aircraft Model 1/150 Air Force One Airplane w/ Undercarriage &Voice Control Lamp',
#  'F22 RC Airplanes Remote Control Fighter Jet RTF Plane Model With 3 Battery US']

# %% [markdown]
# #### Task 8.2
#
# Create a list of all the **item prices** sold on this page. Again, focus only on this first page of results.

# %%
item_prices = [item.text for item in soup.find_all("span", class_="s-item__price")]
item_prices
# Out:
# ['$20.00',
#  '$40.00',
#  '$250.00',
#  '$18.49 to $27.99',
#  '$51.99',
#  '$15.50',
#  '$229.99',
#  '$59.99',
#  '$4.25',
#  '$229.99',
#  '$199.99',
#  '$27.99',
#  '$249.99',
#  '$89.99',
#  '$159.99',
#  '$73.90',
#  '$319.99',
#  '$21.95',
#  '$69.97',
#  '$19.80',
#  '$19.00',
#  '$12.99',
#  '$179.99',
#  '$199.99',
#  '$229.99',
#  '$62.47',
#  '$112.45',
#  '$243.66',
#  '$10.00',
#  '$13.12',
#  '$19.99',
#  '$124.96',
#  '$183.39',
#  '$25.00',
#  '$186.80',
#  '$93.72',
#  '$75.00',
#  '$25.76',
#  '$45.76 to $59.35',
#  '$249.99',
#  '$89.99',
#  '$27.99 to $34.99',
#  '$10.93',
#  '$78.40',
#  '$14.37',
#  '$4.50 to $29.99',
#  '$18.73',
#  '$43.72',
#  '$13.12',
#  '$19.97',
#  '$159.99',
#  '$49.97',
#  '$99.95',
#  '$141.20',
#  '$49.97',
#  '$91.20',
#  '$156.19',
#  '$81.22',
#  '$37.49',
#  '$65.64',
#  '$98.46',
#  '$12.00',
#  '$12.35',
#  '$27.99 to $34.99',
#  '$57.48',
#  '$54.70',
#  '$87.52',
#  '$10.94',
#  '$7.99',
#  '$73.90',
#  '$9.99',
#  '$13.49',
#  '$9.75 to $9.97',
#  '$43.99',
#  '$18.98',
#  '$124.99',
#  '$56.72',
#  '$29.98',
#  '$16.00',
#  '$43.99',
#  '$76.99',
#  '$129.99',
#  '$29.97',
#  '$89.98',
#  '$25.00']

# %% [markdown]
# #### Task 8.3
#
# Combine both lists into a dataframe and print the dataframe. It should show the item names and prices.

# %%
Item_name_prices=pd.DataFrame({'Item Name': pd.Series(item_names), 'Item Price': pd.Series(item_prices)})
Item_name_prices
# Out:
#                                             Item Name        Item Price
# 0                                        Shop on eBay            $20.00
# 1                                   Eflite umx radian            $40.00
# 2   Midwest Super Stinker 11-260 Kit 27% Scale RC ...           $250.00
# 3   Kid Xmas Gift EPP Foam SU-35 Model Plane Toy R...  $18.49 to $27.99
# 4   MiniArt 48001 P-47D-25RE Thunderbolt Advanced ...            $51.99
# ..                                                ...               ...
# 80                                                NaN            $76.99
# 81                                                NaN           $129.99
# 82                                                NaN            $29.97
# 83                                                NaN            $89.98
# 84                                                NaN            $25.00
#
# [85 rows x 2 columns]
